# %% [markdown]
# # ML-IMC data
#
# ## Analysis of ML-IMC training on LJ data
#
# ## The data is obtained with my Julia MC code that can be found here:
#
# (https://github.com/mikhail-a-ivanov/ML-IMC)

# %%
using Plots
using Statistics
using BSON: @save, @load

include("../src/distances.jl")
include("../src/readLJ.jl")
include("../src/ML-IMC.jl");

# %% [markdown]
# I have submitted four ML-IMC simulations on alkluster in total. Three of them use Momentum descent optimizer. I run 50 iterations with learning rate of 0.05 and momentum coefficients of 0.9, 0.75 and 0.5. For reference I run 50 iterations of standard gradient descent  with learning rate of 0.05. All simulation run on 40 CPU cores with each running 10M steps for equilibration and 10M more steps for production. Production data is collected from each core and averaged.

# %% [markdown]
# # 0. Preparation

# %%
HOME = pwd()
# Out:
# "/largedisk/git/ML-IMC/results"

# %%
cd(HOME)

# %%
"""
function readloss(outname)

Reads loss data from ML-IMC output file
"""
function readloss(outname)
    lossdata = []
    file = open(outname, "r")
    lines = readlines(file)
    for line in lines
        if length(split(line)) > 0 && split(line)[1] == "Loss"
            append!(lossdata, parse(Float64, split(line)[end]))
        end
    end
    close(file)
    iters = 1:length(lossdata)
    return(iters, lossdata)
end;

# %%
"""
histname(rdfname)

Reads distance histogram file produced
by ML-IMC.jl
"""
function readhist(histname)
    file = open(histname, "r")
    println("\nReading histogram data from $(histname)...")
    lines = readlines(file)
    ncomments = 1
    nlines = length(lines) - ncomments
    bins = zeros(nlines)
    hist = zeros(nlines)
    for i in (1 + ncomments):length(lines)
        rdfline = split(lines[i])
        if length(rdfline) == 2
            bins[i - ncomments] = parse(Float64, rdfline[1])
            hist[i - ncomments] = parse(Float64, rdfline[2])
        end
    end
    return(bins, hist)
    close(file)
end;

# %% [markdown]
# Reading the reference histogram:

# %%
cd(HOME * "/learning")

# %%
bins, rdfref, histref = readRDF("mcLJ/rdf-mean-p40.dat")
histref ./= 500;
# Out:
# Reading reference data from mcLJ/rdf-mean-p40.dat...

# %% [markdown]
# # 1. Gradient descent

# %%
cd(HOME * "/learning/GD_0.05")

# %%
run(`cat LJML-init.in`)
# Out:
# # System
# box           = 36.405 36.405 36.405 # Box vectors [Å]
#
# # Conditions
# temperature   = 95.0                 # [K]
#
# # Monte Carlo parameters
# delta         = 0.75                 # Max displacement [Å]
# steps         = 2E7                  # Total number of MC steps
# Eqsteps       = 1E7                  # Equilibration MC steps
#
# # Output control
# xyzout        = 0                    # XYZ output frequency
# outfreq       = 1E3                  # Output frequency
#
# # RDF parameters
# binWidth      = 0.025                # [Å]
# Nbins         = 600                  # Number of bins
#
# # Learning parameters
# iters         = 50                  # Number of learning iterations
# activation    = identity             # Activation function
# optimizer     = Descent              # Optimizer (other options - Momentum)
# rate          = 0.05                 # Learning rate
#
# # Input files
# xyzname       = mcLJ/mctraj-p001.xyz   # Input configuration file
# ...

# %%
itersGD, lossdataGD = readloss("p40.out");

# %%
plot(itersGD, lossdataGD, title="Gradient descent optimization", label="η = 0.05", marker=(:dot))
xlabel!("Iteration")
ylabel!("Loss")

# %%
binsGD, histGD = readhist("histNN-iter-50.dat");
# Out:
# Reading histogram data from histNN-iter-50.dat...

# %%
plot(bins, histref, xlim = (2, 15), linewidth=3, labels="Reference", title="Distance histogram", legend=:topleft)
plot!(binsGD, histGD, xlim = (2, 15), linewidth=3, labels="GD - Iteration 50")
xlabel!("Distance, Å")
ylabel!("<S>")

# %%
@load "model-iter-01.bson" model
modelstart = copy(model.weight');

# %%
@load "model-iter-50.bson" model
modelGD = copy(model.weight');

# %%
plot(bins, modelGD, title="Weights", label="GD - Iteration 50", xlim=(2, 15), ylim=(-0.05, 0.05), lw=3)
xlabel!("Distance, Å")
ylabel!("<w>")

# %% [markdown]
# # 2. Momentum descent (μ = 0.9)

# %%
cd(HOME * "/learning/MGD_0.05_0.9")

# %%
run(`cat LJML-init.in`);
# Out:
# # System
# box           = 36.405 36.405 36.405 # Box vectors [Å]
#
# # Conditions
# temperature   = 95.0                 # [K]
#
# # Monte Carlo parameters
# delta         = 0.75                 # Max displacement [Å]
# steps         = 2E7                  # Total number of MC steps
# Eqsteps       = 1E7                  # Equilibration MC steps
#
# # Output control
# xyzout        = 0                    # XYZ output frequency
# outfreq       = 1E3                  # Output frequency
#
# # RDF parameters
# binWidth      = 0.025                # [Å]
# Nbins         = 600                  # Number of bins
#
# # Learning parameters
# iters         = 50                   # Number of learning iterations
# activation    = identity             # Activation function
# optimizer     = Momentum             # Optimizer (other options - Descent)
# rate          = 0.05                 # Learning rate
# momentum      = 0.9                  # Momentum coefficient
#
# # Input files
# ...

# %%
itersMGD09, lossdataMGD09 = readloss("p40.out");

# %%
plot(itersGD, lossdataGD, label="GD: η = 0.05", marker=(:dot))
plot!(itersMGD09, lossdataMGD09, title="Training", 
    label="MGD: η = 0.05\nμ = 0.9", marker=(:dot))
xlabel!("Iteration")
ylabel!("Loss")

# %%
binsMGD09, histMGD09 = readhist("histNN-iter-50.dat");
# Out:
# Reading histogram data from histNN-iter-50.dat...

# %%
plot(bins, histref, xlim = (2, 15), linewidth=3, labels="Reference", title="Distance histogram", legend=:topleft)
plot!(binsMGD09, histMGD09, xlim = (2, 15), linewidth=3, labels="MGD - Iteration 50")
xlabel!("Distance, Å")
ylabel!("<S>")

# %%
@load "model-iter-50.bson" model
modelMGD09 = copy(model.weight');

# %%
plot(bins, modelMGD09, title="Weights", label="MGD - Iteration 50", xlim=(2, 15), ylim=(-0.3, 0.3), lw=3)
xlabel!("Distance, Å")
ylabel!("<w>")

# %% [markdown]
# # 3. Momentum descent (μ = 0.75)

# %%
cd(HOME * "/learning/MGD_0.05_0.75")

# %%
run(`cat LJML-init.in`);
# Out:
# # System
# box           = 36.405 36.405 36.405 # Box vectors [Å]
#
# # Conditions
# temperature   = 95.0                 # [K]
#
# # Monte Carlo parameters
# delta         = 0.75                 # Max displacement [Å]
# steps         = 2E7                  # Total number of MC steps
# Eqsteps       = 1E7                  # Equilibration MC steps
#
# # Output control
# xyzout        = 0                    # XYZ output frequency
# outfreq       = 1E3                  # Output frequency
#
# # RDF parameters
# binWidth      = 0.025                # [Å]
# Nbins         = 600                  # Number of bins
#
# # Learning parameters
# iters         = 50                   # Number of learning iterations
# activation    = identity             # Activation function
# optimizer     = Momentum             # Optimizer (other options - Descent)
# rate          = 0.05                 # Learning rate
# momentum      = 0.75                 # Momentum coefficient
#
# # Input files
# ...

# %%
itersMGD075, lossdataMGD075 = readloss("p40.out");

# %%
plot(itersGD, lossdataGD, label="GD: η = 0.05", marker=(:dot))
plot!(itersMGD09, lossdataMGD09, title="Training", 
    label="MGD: η = 0.05\nμ = 0.9", marker=(:dot))
plot!(itersMGD075, lossdataMGD075, 
    label="MGD: η = 0.05\nμ = 0.75", marker=(:dot))
xlabel!("Iteration")
ylabel!("Loss")

# %%
binsMGD075, histMGD075 = readhist("histNN-iter-50.dat");
# Out:
# Reading histogram data from histNN-iter-50.dat...

# %%
plot(bins, histref, xlim = (2, 15), linewidth=3, labels="Reference", title="Distance histogram", legend=:topleft)
plot!(binsMGD075, histMGD075, xlim = (2, 15), linewidth=3, labels="MGD - Iteration 50")
xlabel!("Distance, Å")
ylabel!("<S>")

# %%
@load "model-iter-50.bson" model
modelMGD075 = copy(model.weight');

# %%
plot(bins, modelMGD075, title="Weights", label="MGD - Iteration 50", xlim=(2, 15), ylim=(-0.3, 0.3), lw=3)
xlabel!("Distance, Å")
ylabel!("<w>")

# %% [markdown]
# # 4. Momentum descent (μ = 0.5)

# %%
cd(HOME * "/learning/MGD_0.05_0.5")

# %%
run(`cat LJML-init.in`);
# Out:
# # System
# box           = 36.405 36.405 36.405 # Box vectors [Å]
#
# # Conditions
# temperature   = 95.0                 # [K]
#
# # Monte Carlo parameters
# delta         = 0.75                 # Max displacement [Å]
# steps         = 2E7                  # Total number of MC steps
# Eqsteps       = 1E7                  # Equilibration MC steps
#
# # Output control
# xyzout        = 0                    # XYZ output frequency
# outfreq       = 1E3                  # Output frequency
#
# # RDF parameters
# binWidth      = 0.025                # [Å]
# Nbins         = 600                  # Number of bins
#
# # Learning parameters
# iters         = 50                   # Number of learning iterations
# activation    = identity             # Activation function
# optimizer     = Momentum             # Optimizer (other options - Descent)
# rate          = 0.05                 # Learning rate
# momentum      = 0.5                  # Momentum coefficient
#
# # Input files
# ...

# %%
itersMGD05, lossdataMGD05 = readloss("p40.out");

# %%
plot(itersGD, lossdataGD, label="GD: η = 0.05", marker=(:dot))
plot!(itersMGD09, lossdataMGD09, title="Training", 
    label="MGD: η = 0.05\nμ = 0.9", marker=(:dot))
plot!(itersMGD075, lossdataMGD075, 
    label="MGD: η = 0.05\nμ = 0.75", marker=(:dot))
plot!(itersMGD05, lossdataMGD05, 
    label="MGD: η = 0.05\nμ = 0.5", marker=(:dot))
xlabel!("Iteration")
ylabel!("Loss")

# %%
binsMGD05, histMGD05 = readhist("histNN-iter-50.dat");
# Out:
# Reading histogram data from histNN-iter-50.dat...

# %%
plot(bins, histref, xlim = (2, 15), linewidth=3, labels="Reference", title="Distance histogram", legend=:topleft)
plot!(binsMGD05, histMGD05, xlim = (2, 15), linewidth=3, labels="MGD - Iteration 50")
xlabel!("Distance, Å")
ylabel!("<S>")

# %%
@load "model-iter-50.bson" model
modelMGD05 = copy(model.weight');

# %%
plot(bins, modelMGD05, title="Weights", label="MGD - Iteration 50", xlim=(2, 15), ylim=(-0.3, 0.3), lw=3)
xlabel!("Distance, Å")
ylabel!("<w>")

# %% [markdown]
# I need to continue training! I will increase learning rate to 0.1, keep experimenting with different momentum coefficients (0.9, 0.75 and 0.5) but will increase the number of iterations to 100.

# %% [markdown]
# I have submitted new MGD runs, new GD run with 0.1 learning rate is in the queue.

# %% [markdown]
# # 5. Summary

# %% [markdown]
# ## Training:

# %%
plot(itersGD, lossdataGD, label="GD: η = 0.05", marker=(:dot))
plot!(itersMGD09, lossdataMGD09, title="Training", 
    label="MGD: η = 0.05\nμ = 0.9", marker=(:dot))
plot!(itersMGD075, lossdataMGD075, 
    label="MGD: η = 0.05\nμ = 0.75", marker=(:dot))
plot!(itersMGD05, lossdataMGD05, 
    label="MGD: η = 0.05\nμ = 0.5", marker=(:dot))
xlabel!("Iteration")
ylabel!("Loss")

# %% [markdown]
# ## Histograms:

# %%
plot(bins, histref, xlim = (2, 15), linewidth=3, labels="Reference", title="Distance histogram", legend=:topleft)
plot!(binsMGD09, histMGD09, xlim = (2, 15), linewidth=3, labels="MGD (μ = 0.9) - Iteration 50")
xlabel!("Distance, Å")
ylabel!("<S>")

# %%
xmin = 3
xmax = 10
ymin = 0.1
ymax = 0.5
plot(bins, histref, xlim = (xmin, xmax), ylim = (ymin, ymax), linewidth=3, labels="Reference", title="Distance histogram", legend=:topleft)
plot!(binsGD, histGD, linewidth=3, linestyle=:dash, labels="GD - Iteration 50")
plot!(binsMGD09, histMGD09, linewidth=3, linestyle=:dash, labels="MGD (μ = 0.9) - Iteration 50")
plot!(binsMGD075, histMGD075, linewidth=3, linestyle=:dash, labels="MGD (μ = 0.75) - Iteration 50")
plot!(binsMGD05, histMGD05, linewidth=3, linestyle=:dash, labels="MGD (μ = 0.5) - Iteration 50")
xlabel!("Distance, Å")
ylabel!("<S>")

# %% [markdown]
# ## Models:

# %%
xmin = 2
xmax = 15
ymin = -0.3
ymax = 0.3
plot(bins, modelGD, title="Weights", label="GD - Iteration 50", xlim=(xmin, xmax), ylim=(ymin, ymax), lw=3)
plot!(bins, modelMGD09, title="Weights", label="MGD (μ = 0.9) - Iteration 50", lw=3)
plot!(bins, modelMGD075, title="Weights", label="MGD (μ = 0.75) - Iteration 50", lw=3)
plot!(bins, modelMGD05, title="Weights", label="MGD (μ = 0.5) - Iteration 50", lw=3)
xlabel!("Distance, Å")
ylabel!("<w>")

# %%
plot(bins, modelstart, title="Weights", label="Starting model", xlim=(0, 5), lw=3)
xlabel!("Distance, Å")
ylabel!("<w>")

# %%
"""
function repulsion(hist, parameters, shift=0.01, stiffness=500)

Returns repulsion weights for the neural network
Functional form for repulsion: stiffness*[exp(-αr)-shift]
α is a coefficient that makes sure that the repulsion term
goes to zero at minimal distance from the given histogram
"""
function repulsion(hist, parameters, shift=0.01, stiffness=500)
    bins = [bin*parameters.binWidth for bin in 1:parameters.Nbins]
    minDistance = mindistance(hist, parameters)
    # Find α so that [exp(-αr) - shift] goes to zero at minDistance
    α = -log(shift)/minDistance
    potential = zeros(Float32, parameters.Nbins)
    for i in 1:parameters.Nbins
        if bins[i] < minDistance
            potential[i] = stiffness*(exp(-α*bins[i])-shift)
        end
    end
    return(potential)
end;
